# %% [markdown]
# <h3 style = "color:green">Introduction

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px">
# <p align = 'center'>
#
# Air quality is an important environmental indicator that directly affects human health and quality of life. This dataset contains daily Air Quality Index (AQI) measurements for countries around the world, providing insights into pollution levels and air quality trends over time. The objective of this analysis is to explore global AQI patterns, identify temporal trends and seasonal variations, compare air quality across different regions, and uncover factors that may influence pollution levels. Through exploratory data analysis and visualization, this project aims to develop a better understanding of worldwide air quality conditions and lay the foundation for future forecasting and predictive modeling.
# </p>
# </div>

# %%
import numpy as np
import pandas as pd
import polars as pl

from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

# %% [markdown]
# <h3 style = "color:green">1. Getting Ready with data

# %%
data = pl.read_csv('/home/kartika/Datasets/aqi_data.csv')
data = data.to_pandas()

data.head(10)
# Out:
#          Date     Country                          Status  AQI Value
# 0  2022-07-21     Albania                            Good         14
# 1  2022-07-21     Algeria                        Moderate         65
# 2  2022-07-21     Andorra                        Moderate         55
# 3  2022-07-21      Angola  Unhealthy for Sensitive Groups        113
# 4  2022-07-21   Argentina                        Moderate         63
# 5  2022-07-21     Armenia                        Moderate         76
# 6  2022-07-21   Australia                        Moderate         56
# 7  2022-07-21     Austria                            Good         45
# 8  2022-07-21  Azerbaijan                            Good         12
# 9  2022-07-21     Bahrain                       Unhealthy        165

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25333 entries, 0 to 25332
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       25333 non-null  object
#  1   Country    25333 non-null  object
#  2   Status     25333 non-null  object
#  3   AQI Value  25333 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 791.8+ KB

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px">No null values.

# %%
data.duplicated().sum()
# Out:
# np.int64(300)

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px">Date, country and status have no duplicate values. AQI can have duplicate values.

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25333 entries, 0 to 25332
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       25333 non-null  datetime64[ns]
#  1   Country    25333 non-null  object
#  2   Status     25333 non-null  object
#  3   AQI Value  25333 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 791.8+ KB

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px">Converted date object to datetime.

# %% [markdown]
# <div>

# %% [markdown]
# <div>

# %% [markdown]
# <h3 style = "color:green">2. Univariate Analysis

# %% [markdown]
# <h3 style = "color:green">2.1 Country
