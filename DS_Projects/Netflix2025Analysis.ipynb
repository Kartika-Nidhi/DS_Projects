# %% [markdown]
# <h3 style = "color:green">INTRODUCTION

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">
# Netflix is one of the world's leading streaming platforms, offering a vast collection of movies and TV shows across different genres, languages, and regions. This dataset, sourced from TMDb (The Movie Database), contains detailed information about Netflix content, including titles, genres, release dates, ratings, and descriptions. The dataset has been cleaned and structured to ensure consistency, making it suitable for exploratory data analysis (EDA). Through EDA, we can gain insights into Netflix's content library, identify patterns in content production, and understand trends in genres, ratings, and release years.
# </div>

# %% [markdown]
# <h3 style = "color:green">OBJECTIVES

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">
# <ul>
# <li>Analyze the distribution of movies and TV shows available on Netflix.
# <li>Explore content trends across release years.
# <li>Identify the most common genres and content categories.
# <li>Examine the distribution of ratings and audience classifications.
# <li>Investigate patterns in content duration and popularity-related attributes.
# <li>Discover relationships between different content features and uncover key insights about Netflix's catalog.
# <li>Generate findings that can support content recommendation and business decision-making.
#
# </div>

# %% [markdown]
# <h3 style = "color:green">Getting Ready With Data

# %%
import numpy as np
import pandas as pd
import polars as pl

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

# %%
data = pl.read_csv('/home/kartika/Datasets/netflix_movies_detailed_up_to_2025.csv')
data = data.to_pandas()
data.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
data.tail()
# Out:
#        show_id   type                                  title  \
# 15995  1440286  Movie  Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                          Man and Woman
# 15997  1426364  Movie       Night of the Dead Sorority Babes
# 15998  1411248  Movie                        A Dunces Burden
# 15999  1405742  Movie                         Portal to Hell
#
#                                     director  \
# 15995                                   None
# 15996                          Vladimir Kott
# 15997  Angel Nichole Bradford, Steve Hermann
# 15998                           Daniel Kowal
# 15999                             Woody Bess
#
#                                                     cast  \
# 15995                                             Ha*ash
# 15996  Anna Kotova, Stepan Devonin, Pavel Derevyanko,...
# 15997  Jessa Flux, Lynn Lowry, Angel Nichole Bradford...
# 15998                           Riley G, Mitchel Corrado
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      15868 non-null  object
#  4   cast          15796 non-null  object
#  5   country       15534 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      object
#  10  genres        15893 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director          132
# cast              204
# country           466
# date_added          0
# release_year        0
# rating              0
# duration        16000
# genres            107
# language            0
# description       132
# popularity          0
# vote_count          0
# vote_average        0
# budget              0
# revenue             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">There are some missing values(blank values) in director, cast, country, genres and description fields which will be handled during their respective analysis. No duplicate values are present.

# %%
data.drop(columns = ['show_id', 'type', 'description', 'title', 'cast', 'duration'], inplace = True)

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Dropped unnecessary columns.

# %%
data.index[data.index.duplicated()]
# Out:
# Index([    0,     0,     0,     0,     1,     1,     2,     3,     3,     4,
#        ...
#        15987, 15987, 15988, 15988, 15989, 15989, 15989, 15991, 15991, 15999],
#       dtype='int64', length=21567)

# %%
data = data[~data.index.duplicated(keep = 'first')]

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Removed duplicate labels.

# %% [markdown]
# <div>

# %% [markdown]
# <h3 style = "color:green">Univariate Analysis

# %% [markdown]
# <h4 style = "color:green">Top Countries

# %%
data.country.isnull().sum()
# Out:
# np.int64(466)

# %%
data['country'] = data['country'].fillna('Unknown')

# %%
data.country.value_counts()
# Out:
# country
# United States of America                                        5421
# Japan                                                            845
# South Korea                                                      789
# France                                                           612
# United Kingdom                                                   581
#                                                                 ...
# Argentina, Colombia, Venezuela                                     1
# Luxembourg, Belgium, France                                        1
# China, France, Hong Kong, Taiwan                                   1
# South Korea, Spain, United Kingdom, United States of America       1
# Belgium, Finland, France, Mexico, Netherlands                      1
# Name: count, Length: 1464, dtype: int64

# %%
plt.barh(
        width = data['country'].value_counts().head(10).values,
        y= data['country'].value_counts().head(10).index,
        color = plt.cm.Blues(np.linspace(1, 0.8, 10)),
        linewidth = 1.5,
        edgecolor = 'lightgreen',

)

plt.title('Top 10 Countries')
plt.xlabel('Count')
plt.gca().invert_yaxis()
plt.ylabel('Countries')
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">USA has most movies in the dataset, follwed by Japan and South Korea with high margin. Significant number of values are missing as well.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Top Languages

# %%
data['language'].value_counts()
# Out:
# language
# en    9534
# fr    1054
# ja     904
# ko     876
# es     731
#       ...
# ur       1
# ht       1
# hy       1
# sl       1
# bg       1
# Name: count, Length: 74, dtype: int64

# %%
plt.barh(
        width = data['language'].value_counts().head(10).values,
        y= data['language'].value_counts().head(10).index,
        color = plt.cm.Blues(np.linspace(1, 0.8, 10)),
        linewidth = 1.5,
        edgecolor = 'lightgreen',

)

plt.title('Top 10 Languages')
plt.xlabel('Count')
plt.gca().invert_yaxis()
plt.ylabel('Languages')
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">The dataset is heavily dominated by English movies, followed by French movies by great margin.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Top Directors

# %%
data['director'].isnull().sum()
# Out:
# np.int64(132)

# %%
data['director'] = data['director'].fillna('Unknown')

# %%
plt.barh(
        width = data['director'].value_counts().head(10).values,
        y= data['director'].value_counts().head(10).index,
        color = plt.cm.Greens(np.linspace(1, 0.8, 10)),
        linewidth = 1.5,
        edgecolor = 'lightblue',

)

plt.title('Top 10 Directors')
plt.xlabel('Count')
plt.gca().invert_yaxis()
plt.ylabel('Directors')
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">More than 50% of the records in director field is missing. In the present records, top director by number of movies are Tyler Perry, Roel Reine and Steven Soderbergh.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Rating Distribution

# %%
data['rating'].describe()
# Out:
# count    16000.000000
# mean         5.956368
# std          1.754741
# min          0.000000
# 25%          5.600000
# 50%          6.300000
# 75%          6.923000
# max         10.000000
# Name: rating, dtype: float64

# %%
data['rating'].skew()
# Out:
# np.float64(-2.116594502398236)

# %%
sns.boxplot(
    data = data,
    x = 'rating',
    showmeans = True
)

plt.title('Rating Distribution')
plt.show()

# %%
sns.histplot(
    data = data,
    x = 'rating',
    bins = 10,
    kde = True
)

plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">The distribution is moderately negatively skewed, indicating most of the movies have high rating and very few movies have unusual low rating.

# %%
data['rating_category'] = pd.cut(data['rating'],
                                 bins = [0, 2, 4, 6, 8, 10],
                                 labels = ['Very Bad', 'Bad', 'Average', 'Good', 'Excellent'])

plt.bar(
    x = data['rating_category'].value_counts().index,
    height = data['rating_category'].value_counts().values,
    color = plt.cm.BuPu(np.linspace(1, 0.5, 5)),
    linewidth = 1.5,
    edgecolor = 'lightgreen'
)

plt.title('Movies by Rating')
plt.xlabel('Ratings')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Most of the movies have rating above average, very few have bad rating.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Genres

# %%
data = data.assign(
    genres=data['genres'].str.split(",")).explode('genres')

# %%
data['genres'].isnull().sum()
# Out:
# np.int64(107)

# %%
data.fillna({'genres': 'Unknown'}, inplace = True)

# %%
data['genres'].value_counts().head(10)
# Out:
# genres
# Drama         3634
#  Drama        3276
#  Thriller     2808
# Comedy        2352
#  Comedy       2181
# Action        1883
#  Romance      1657
# Horror        1520
#  Adventure    1387
#  Action       1356
# Name: count, dtype: int64

# %%
plt.barh(
     y = data['genres'].value_counts().head(10).index,
     width = data['genres'].value_counts().head(10).values,
     color = plt.cm.BuPu(np.linspace(1, 0.9, 10)),
     linewidth = 1.5,
     edgecolor = 'pink'
)

plt.title('Top Genres')
plt.xlabel('Genres')
plt.ylabel('Count')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Drama genre dominates the dataset by high margin. Comedy and Animation are moderately represented.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Budget Distribution

# %%
data['budget'] = data['budget'].replace(0, np.nan)
data['budget'].isnull().sum()
# Out:
# np.int64(25239)

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">The column has a lot of missing values, which were represented as 0,so replaced with np.nan.

# %%
data['budget'].describe()
# Out:
# count    1.232800e+04
# mean     3.378948e+07
# std      5.128622e+07
# min      1.000000e+00
# 25%      4.500000e+06
# 50%      1.300000e+07
# 75%      3.800000e+07
# max      4.600000e+08
# Name: budget, dtype: float64

# %%
data['budget'].skew()
# Out:
# np.float64(2.7217126353361185)

# %%
sns.histplot(
    data = data.loc[data['budget'].notna()],
    x = 'budget',
    bins = 20,
    color = 'green',
    kde = True
)

plt.title('Movies Budget Distribution')
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">The budget distribution is highly right-skewed, indicating most of the movies have low to medium budget (around mean), while few movies have very high budget.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Revenue Distribution

# %%
data['revenue'] = data['revenue'].replace(0, np.nan)
data['revenue'].isnull().sum()
# Out:
# np.int64(23207)

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">The column has a lot of missing values which were represented with 0, so replaced with np.nan.

# %%
data['revenue'].describe()
# Out:
# count    1.436000e+04
# mean     8.233592e+07
# std      1.990556e+08
# min      2.000000e+00
# 25%      1.396905e+06
# 50%      1.087035e+07
# 75%      6.200000e+07
# max      2.799439e+09
# Name: revenue, dtype: float64

# %%
data['revenue'].skew()
# Out:
# np.float64(4.831604725299882)

# %%
sns.histplot(
    data = data.loc[data['revenue'].notna()],
    x = 'revenue',
    bins = 20,
    color = 'blue',
    kde = True

)

plt.title('Revenue Disribution')
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">The revenue distribution is extremely right-skewed. Most of the movies have revenue low and below around mean, while few movies have exceptionally high revenue.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Number of Movies Based on Year

# %%
data['release_year'].value_counts()
# Out:
# release_year
# 2010    2468
# 2022    2467
# 2017    2451
# 2018    2448
# 2021    2430
# 2015    2417
# 2023    2412
# 2016    2406
# 2019    2390
# 2011    2380
# 2012    2358
# 2024    2289
# 2014    2285
# 2013    2258
# 2020    2237
# 2025    1871
# Name: count, dtype: int64

# %% [markdown]
# <div>

# %% [markdown]
# <div>

# %% [markdown]
# <h3 style = "color:green">Bivariate Analysis

# %% [markdown]
# <h4 style = "color:green">Rating vs Vote Count

# %%
data['rating'].describe()
# Out:
# count    37567.000000
# mean         6.091833
# std          1.579150
# min          0.000000
# 25%          5.700000
# 50%          6.400000
# 75%          7.000000
# max         10.000000
# Name: rating, dtype: float64

# %%
data['vote_count'].describe()
# Out:
# count    37567.000000
# mean       841.478478
# std       2313.112683
# min          0.000000
# 25%         63.000000
# 50%        158.000000
# 75%        503.000000
# max      37119.000000
# Name: vote_count, dtype: float64

# %%
data['rating'].corr(data['vote_count'])
# Out:
# np.float64(0.1777998435639997)

# %%
plt.scatter(
    x = data['rating'],
    y = data['vote_count'],
    color = 'green', 
    alpha = 0.5,
    edgecolor = 'lightblue'
)

plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">There is a very weak positive linear relationship between rating and number of votes.

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Also, highly voted movies have a massive spread of ratings.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green"> Country vs Genres

# %%
top_countries = data['country'].value_counts().head(5).index

data_top_countries = data[data['country'].isin(top_countries)]


genre_counts = (
    data_top_countries.groupby(
        ['country', 'genres']
    ).size().reset_index(name = 'count')
)

top_genres = (
    genre_counts.sort_values(['country', 'count']).groupby('country', as_index = False).head(5)
)

g = sns.catplot(
    data = top_genres,
    x = 'count',
    y = 'genres',
    col = 'country',
    kind = 'bar',
    col_wrap = 2,
    height = 4,
    sharex = False,
    sharey = False
)

g.set_axis_labels("Number of Movies", "Genre")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Top countries have various preferences over different genres of movies.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Country vs Rating

# %%
plt.barh(
    y = data.groupby('country')['rating'].count().nlargest(10).index,
    width = data.groupby('country')['rating'].mean().nlargest(10).values,
    color = plt.cm.BuPu(np.linspace(1, 0.9, 10)),
    linewidth = 1.5,
    edgecolor = 'lightgreen'
)

plt.axvline(x = data['rating'].mean(), color = 'red', linestyle = '--', linewidth = 1.5)
plt.title('Countries vs Rating')
plt.ylabel('Countries')
plt.xlabel('Mean Rating')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">USA and Japan have the most highest rated movies, with perfect mean score.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Genres vs Popularity

# %%
plt.barh(
    y = data.groupby('genres')['popularity'].mean().sort_values().nlargest(10).index,
    width = data.groupby('genres')['popularity'].mean().sort_values().nlargest(10).values,
    color = plt.cm.Purples(np.linspace(1, 0.9, 10)),
    linewidth = 1.5,
    edgecolor = 'lightgreen',
      )

plt.title('Genres vs Popularity')
plt.ylabel('Genres')
plt.xlabel('Mean Popularity')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Science Fiction, Adventure and Action are most popular genres.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Genres vs Rating

# %%
plt.barh(
    y = data.groupby('genres')['rating'].mean().sort_values().nlargest(10).index,
    width = data.groupby('genres')['rating'].mean().sort_values().nlargest(10).values,
    color = plt.cm.Purples(np.linspace(1, 0.9, 10)),
    linewidth = 1.5,
    edgecolor = 'lightgreen',
      )

plt.title('Genres vs Rating')
plt.ylabel('Genres')
plt.xlabel('Mean Rating')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Documentary and animation are the most rated genres.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Genres vs Budget

# %%
plt.barh(
    y = data.groupby('genres')['budget'].mean().sort_values().nlargest(10).index,
    width = data.groupby('genres')['budget'].mean().sort_values().nlargest(10).values,
    color = plt.cm.Purples(np.linspace(1, 0.9, 10)),
    linewidth = 1.5,
    edgecolor = 'lightgreen',
      )

plt.title('Genres vs Budget')
plt.ylabel('Genres')
plt.xlabel('Mean Budget')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Adventures movies have high budget compared to other genres of movies.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Genres vs Revenue

# %%
plt.barh(
    y = data.groupby('genres')['revenue'].mean().sort_values().nlargest(10).index,
    width = data.groupby('genres')['revenue'].mean().sort_values().nlargest(10).values,
    color = plt.cm.Purples(np.linspace(1, 0.9, 10)),
    linewidth = 1.5,
    edgecolor = 'lightgreen',
      )

plt.title('Genres vs Revenue')
plt.ylabel('Genres')
plt.xlabel('Mean Revenue')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">Adventure and Science Fiction genres generate the most revenue.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green">Budget vs Revenue

# %%
data['budget'].corr(data['revenue'])
# Out:
# np.float64(0.7429210416235181)

# %%
sns.scatterplot(
    data = data,
    x = 'budget',
    y = 'revenue',
    color = 'green',
    edgecolor = 'lightblue'
    
)

plt.title('Budget vs Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
sns.despine()
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">There is a strong positive linear relationship between budget and revenue, indicating if the budget is high, the movie is likely to generate high revenue.

# %% [markdown]
# <div>

# %% [markdown]
# <h4 style = "color:green"> Top Genres over Years (2010-2025)

# %%
genres_over_year = data.groupby(['release_year', 'genres'])['popularity'].mean().reset_index()

pivot = genres_over_year.pivot(index = 'genres', columns = 'release_year', values = 'popularity')
sns.heatmap(pivot, cmap = 'YlOrRd', annot = False)
plt.title('Genre popularity over years')
plt.show()

# %%
top_one = genres_over_year.loc[genres_over_year.groupby('release_year')['popularity'].idxmax()]

sns.barplot(
    data = top_one,
    x = 'release_year', 
    y = 'popularity',
    hue = 'genres',
    dodge = False
)

plt.title('Most Popular genre Over Years')
plt.xlabel('Release Year')
plt.xticks(rotation = 45)
plt.ylabel('Mean Popularity')
plt.show()

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">The graph shows popularity of different genres over 16 years. In recent years, adventure and romance is more popular.

# %% [markdown]
# <div>

# %% [markdown]
# <h3 style = "color:green">Major Findings

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">
# <ul>
# <li>USA has most number of movies in the datset from North and Latin America. From Asia, Japan and South Korea have most movies. Similarly, France and UK have most movies from Europe.
# <li>The movies are heavily dominated by English movies.
# <li>Most movies have above average rating, while very few have unusual low rating.
# <li>USA, Japan and South Korea have most highly rated movies.
# <li>Most movies are made with low to medium budget, while few have very high budget.
# <li>Revenue has also same kind of trend, with most movies earing low to medium, while fe earing exceptionally high.
# <li>The trend also, shows that high budget movies are likely to genrate high revenue.
# </ul>
# </div>

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">
# <ul>
# <li>By number of movies - Drama, Thriller and Comedy are top genres.
# <li>By popularity - Science Fiction, Adventure and Action are top genres.
# <li>By rating - Documentary, Animation and History are top genres.
# <li>By budget - Adventure, Fantasy and Science Fiction are top genres.
# <li>By revenue - Adventure, Science Fiction and Adventure are top genres.
# <li>Adventure and Fantasy are most popular genres in recent years.
# <ul>
# <div>

# %% [markdown]
# <h3 style = "color:green">Suggestions and Recommendations

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px; text-align:justify">
# <ul>
#
# <li>Expand Regional Content Production:
# While the United States dominates the movie catalog, increasing investments in emerging film industries across Asia, Africa, and Latin America could help diversify the content library and attract a broader global audience.
#
# <li>Increase Multilingual Content:
# Since English-language movies make up the majority of the dataset, producing and promoting more high-quality movies in regional and international languages can improve audience reach and strengthen Netflix's presence in non-English-speaking markets.
#
# <li>Continue Investing in High-Quality Productions:
# Most movies receive above-average ratings, indicating that maintaining strong production quality should remain a priority. Audience preferences and critical feedback should continue to guide content development.
#
# <li>Strengthen Partnerships with High-Performing Countries:
# Countries such as the United States, Japan, and South Korea consistently produce highly rated movies. Expanding collaborations with filmmakers and production studios in these regions could further enhance content quality.
#
# <li>Maintain a Balanced Budget Strategy:
# Since most successful movies are produced with low to medium budgets, Netflix should continue investing in cost-effective productions while selectively funding high-budget projects with strong commercial potential.
#
# <li>Prioritize High-Return Investments:
# The positive relationship between production budget and revenue suggests that carefully selected high-budget films can generate substantial financial returns. Investment decisions should focus on projects with strong market demand and franchise potential.
#
# <li>Focus on Popular and Profitable Genres:
# Drama, Thriller, and Comedy consistently attract high production volumes, while Adventure, Science Fiction, and Fantasy generate higher popularity and revenue. Maintaining a balanced portfolio of these genres can maximize both audience engagement and profitability.
#
# <li>Promote Critically Acclaimed Genres:
# Documentary, Animation, and History movies achieve the highest average ratings despite having relatively fewer releases. Increasing the production and promotion of these genres could improve overall audience satisfaction and critical recognition.
#
# <li>Capitalize on Emerging Genre Trends:
# The growing popularity of Adventure and Fantasy movies in recent years suggests shifting viewer preferences. Expanding investment in these genres may help sustain future audience growth.
#
# <li>Leverage Data-Driven Content Planning:
# Regular analysis of ratings, popularity, budgets, revenues, genres, and regional performance should be incorporated into content acquisition and production strategies to support informed business decisions and optimize return on investment.
#
# <ul>
# <div>
