# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px">
#
# This project performs an Exploratory Data Analysis (EDA) on the Instagram User Lifestyle Analysis dataset. The analysis aims to understand user demographics, posting habits, engagement levels, content preferences, and other factors that characterize user behavior on Instagram. Through statistical summaries and visualizations, the project seeks to uncover meaningful patterns, trends, and relationships within the dataset.</div>

# %%
import numpy as np
import pandas as pd
import polars as pl

from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

# %% [markdown]
# <h3 style = "color:purple">1.Loading Data

# %%
data = pl.read_csv('/home/kartika/Datasets/instagram_users_lifestyle.csv')
data = data.to_pandas()
data.head(20)
# Out:
#     user_id   app_name  age             gender         country urban_rural  \
# 0         1  Instagram   51             Female           India       Rural
# 1         2  Instagram   64             Female  United Kingdom       Urban
# 2         3  Instagram   41             Female          Canada       Urban
# 3         4  Instagram   27         Non-binary     South Korea       Urban
# 4         5  Instagram   55               Male           India       Urban
# 5         6  Instagram   20               Male   United States       Rural
# 6         7  Instagram   33         Non-binary           Japan       Urban
# 7         8  Instagram   51             Female  United Kingdom       Urban
# 8         9  Instagram   31             Female  United Kingdom       Urban
# 9        10  Instagram   35               Male   United States       Urban
# 10       11  Instagram   23               Male           India    Suburban
# 11       12  Instagram   23               Male   United States       Urban
# 12       13  Instagram   36             Female       Australia       Urban
# 13       14  Instagram   65               Male           Japan       Urban
# 14       15  Instagram   48             Female  United Kingdom       Urban
# 15       16  Instagram   52             Female           Japan       Urban
# 16       17  Instagram   36               Male          Brazil       Urban
# 17       18  Instagram   15               Male          Brazil       Urban
# 18       19  Instagram   34             Female          Brazil       Urban
# 19       20  Instagram   65  Prefer not to say          Brazil    Suburban
#
#     income_level   employment_status education_level relationship_status  ...  \
# 0           High             Retired      Bachelor’s              Single  ...
# 1         Middle  Full-time employed           Other            Divorced  ...
# 2         Middle             Student      Bachelor’s   In a relationship  ...
# 3         Middle          Unemployed        Master’s   In a relationship  ...
# 4   Upper-middle  Full-time employed      Bachelor’s              Single  ...
# 5         Middle  Full-time employed      Bachelor’s             Married  ...
# 6   Lower-middle          Freelancer     High school   In a relationship  ...
# 7         Middle  Full-time employed           Other              Single  ...
# 8   Upper-middle             Retired     High school              Single  ...
# 9            Low             Student     High school             Married  ...
# 10           Low  Full-time employed      Bachelor’s   In a relationship  ...
# 11          High  Full-time employed      Bachelor’s            Divorced  ...
# 12        Middle  Full-time employed    Some college              Single  ...
# 13        Middle  Full-time employed     High school             Widowed  ...
# 14        Middle  Full-time employed      Bachelor’s              Single  ...
# 15          High          Freelancer      Bachelor’s              Single  ...
# 16  Lower-middle  Full-time employed    Some college              Single  ...
# 17        Middle        Not employed      Bachelor’s              Single  ...
# 18           Low             Retired     High school   In a relationship  ...
# 19           Low  Full-time employed      Bachelor’s             Married  ...
#
#    last_login_date  average_session_length_minutes  content_type_preference  \
# 0       2025-11-02                             5.0                    Mixed
# 1       2025-03-22                            14.8                   Photos
# 2       2025-08-10                             5.0                    Mixed
# 3       2025-03-31                            25.9                  Stories
# 4       2025-03-19                            13.1                   Videos
# 5       2025-02-09                            16.3                   Photos
# 6       2025-05-06                            31.2                   Photos
# 7       2025-11-17                            20.1                   Videos
# 8       2025-05-10                            12.8                    Reels
# 9       2025-09-13                            15.1                    Reels
# 10      2025-11-11                            26.7                   Videos
# 11      2025-04-25                            24.6                    Mixed
# 12      2025-01-23                             5.0                    Mixed
# 13      2025-05-31                             5.0                     Live
# 14      2025-06-18                             8.1                    Reels
# 15      2025-06-28                             5.0                   Photos
# 16      2025-05-23                            10.9                   Photos
# 17      2025-11-19                            22.5                     Live
# 18      2025-06-30                            28.0                    Reels
# 19      2025-09-08                            24.0                  Stories
#
#    preferred_content_theme privacy_setting_level two_factor_auth_enabled  \
# 0                     Tech               Private                     Yes
# 1                  Fashion                Public                      No
# 2                    Other                Public                     Yes
# 3                     Tech               Private                      No
# 4                     Food                Public                     Yes
# 5                     Food          Friends only                     Yes
# 6                     Tech          Friends only                     Yes
# 7                   Travel                Public                      No
# 8                      Art                Public                     Yes
# 9                     Tech          Friends only                     Yes
# 10                    Tech                Public                     Yes
# 11                     Art          Friends only                     Yes
# 12                 Fashion                Public                      No
# 13                  Travel          Friends only                     Yes
# 14                 Fashion               Private                      No
# 15                   Other               Private                     Yes
# 16                   Music                Public                     Yes
# 17                   Other                Public                      No
# 18                     Art          Friends only                     Yes
# 19                  Travel               Private                      No
#
#     biometric_login_used  linked_accounts_count  subscription_status  \
# 0                     No                      0                 Free
# 1                     No                      3                 Free
# 2                    Yes                      1                 Free
# 3                     No                      1                 Free
# 4                     No                      0                 Free
# 5                    Yes                      1                 Free
# 6                     No                      3                 Free
# 7                     No                      2                 Free
# 8                    Yes                      2                 Free
# 9                     No                      1                 Free
# 10                    No                      2                 Free
# 11                   Yes                      0                 Free
# 12                   Yes                      2              Premium
# 13                   Yes                      2                 Free
# 14                    No                      0                 Free
# 15                    No                      2                 Free
# 16                    No                      2             Business
# 17                    No                      2              Premium
# 18                   Yes                      3                 Free
# 19                   Yes                      1                 Free
#
#     user_engagement_score
# 0                    7.83
# 1                    1.43
# 2                    9.67
# 3                    0.94
# 4                    1.03
# 5                    1.64
# 6                    1.12
# 7                    0.96
# 8                    0.99
# 9                    1.02
# 10                   1.06
# 11                   1.20
# 12                   7.17
# 13                   8.50
# 14                   0.96
# 15                   8.67
# 16                   0.97
# 17                   1.01
# 18                   1.00
# 19                   1.25
#
# [20 rows x 58 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1547896 entries, 0 to 1547895
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   user_id                         1547896 non-null  int64
#  1   app_name                        1547896 non-null  object
#  2   age                             1547896 non-null  int64
#  3   gender                          1547896 non-null  object
#  4   country                         1547896 non-null  object
#  5   urban_rural                     1547896 non-null  object
#  6   income_level                    1547896 non-null  object
#  7   employment_status               1547896 non-null  object
#  8   education_level                 1547896 non-null  object
#  9   relationship_status             1547896 non-null  object
#  10  has_children                    1547896 non-null  object
#  11  exercise_hours_per_week         1547896 non-null  float64
#  12  sleep_hours_per_night           1547896 non-null  float64
#  13  diet_quality                    1547896 non-null  object
#  14  smoking                         1547896 non-null  object
#  15  alcohol_frequency               1547896 non-null  object
#  16  perceived_stress_score          1547896 non-null  int64
#  17  self_reported_happiness         1547896 non-null  int64
#  18  body_mass_index                 1547896 non-null  float64
#  19  blood_pressure_systolic         1547896 non-null  int64
#  20  blood_pressure_diastolic        1547896 non-null  int64
#  21  daily_steps_count               1547896 non-null  int64
#  22  weekly_work_hours               1547896 non-null  float64
#  23  hobbies_count                   1547896 non-null  int64
#  24  social_events_per_month         1547896 non-null  int64
#  25  books_read_per_year             1547896 non-null  int64
#  26  volunteer_hours_per_month       1547896 non-null  float64
#  27  travel_frequency_per_year       1547896 non-null  int64
#  28  daily_active_minutes_instagram  1547896 non-null  float64
#  29  sessions_per_day                1547896 non-null  int64
#  30  posts_created_per_week          1547896 non-null  int64
#  31  reels_watched_per_day           1547896 non-null  int64
#  32  stories_viewed_per_day          1547896 non-null  int64
#  33  likes_given_per_day             1547896 non-null  int64
#  34  comments_written_per_day        1547896 non-null  int64
#  35  dms_sent_per_week               1547896 non-null  int64
#  36  dms_received_per_week           1547896 non-null  int64
#  37  ads_viewed_per_day              1547896 non-null  int64
#  38  ads_clicked_per_day             1547896 non-null  int64
#  39  time_on_feed_per_day            1547896 non-null  int64
#  40  time_on_explore_per_day         1547896 non-null  int64
#  41  time_on_messages_per_day        1547896 non-null  int64
#  42  time_on_reels_per_day           1547896 non-null  int64
#  43  followers_count                 1547896 non-null  int64
#  44  following_count                 1547896 non-null  int64
#  45  uses_premium_features           1547896 non-null  object
#  46  notification_response_rate      1547896 non-null  float64
#  47  account_creation_year           1547896 non-null  int64
#  48  last_login_date                 1547896 non-null  object
#  49  average_session_length_minutes  1547896 non-null  float64
#  50  content_type_preference         1547896 non-null  object
#  51  preferred_content_theme         1547896 non-null  object
#  52  privacy_setting_level           1547896 non-null  object
#  53  two_factor_auth_enabled         1547896 non-null  object
#  54  biometric_login_used            1547896 non-null  object
#  55  linked_accounts_count           1547896 non-null  int64
#  56  subscription_status             1547896 non-null  object
#  57  user_engagement_score           1547896 non-null  float64
# dtypes: float64(9), int64(29), object(20)
# memory usage: 685.0+ MB

# %% [markdown]
# <div style = "background-color:lightblue; color:green; font-size:20px">No missing values.

# %%
data.columns
# Out:
# Index(['user_id', 'app_name', 'age', 'gender', 'country', 'urban_rural',
#        'income_level', 'employment_status', 'education_level',
#        'relationship_status', 'has_children', 'exercise_hours_per_week',
#        'sleep_hours_per_night', 'diet_quality', 'smoking', 'alcohol_frequency',
#        'perceived_stress_score', 'self_reported_happiness', 'body_mass_index',
#        'blood_pressure_systolic', 'blood_pressure_diastolic',
#        'daily_steps_count', 'weekly_work_hours', 'hobbies_count',
#        'social_events_per_month', 'books_read_per_year',
#        'volunteer_hours_per_month', 'travel_frequency_per_year',
#        'daily_active_minutes_instagram', 'sessions_per_day',
#        'posts_created_per_week', 'reels_watched_per_day',
#        'stories_viewed_per_day', 'likes_given_per_day',
#        'comments_written_per_day', 'dms_sent_per_week',
#        'dms_received_per_week', 'ads_viewed_per_day', 'ads_clicked_per_day',
#        'time_on_feed_per_day', 'time_on_explore_per_day',
#        'time_on_messages_per_day', 'time_on_reels_per_day', 'followers_count',
#        'following_count', 'uses_premium_features',
#        'notification_response_rate', 'account_creation_year',
#        'last_login_date', 'average_session_length_minutes',
#        'content_type_preference', 'preferred_content_theme',
#        'privacy_setting_level', 'two_factor_auth_enabled',
#        'biometric_login_used', 'linked_accounts_count', 'subscription_status',
#        'user_engagement_score'],
#       dtype='object')

# %%
cols_to_drop = [
    'user_id', 'app_name',
    'relationship_status','has_children',
    'books_read_per_year', 'volunteer_hours_per_month', 
    'travel_frequency_per_year','daily_steps_count',
    'hobbies_count', 'social_events_per_month',
    'time_on_explore_per_day', 'time_on_messages_per_day',
    'ads_viewed_per_day', 'ads_clicked_per_day',
    'content_type_preference', 'preferred_content_theme',
    'dms_sent_per_week', 'dms_received_per_week',
    'linked_accounts_count','last_login_date',
    'uses_premium_features', 'subscription_status',
    'privacy_setting_level', 'two_factor_auth_enabled',
    'biometric_login_used','notification_response_rate',
    'account_creation_year','last_login_date',
    'privacy_setting_level','two_factor_auth_enabled',
    'biometric_login_used','linked_accounts_count',
    'subscription_status'
  
]

data = data.drop(columns=cols_to_drop)
print(data.shape)
# Out:
# (1547896, 31)

# %% [markdown]
# <div style = " color:green; font-size:10px">
#
# <ul>
#     <li><strong>Target variable</strong>
#       <ul>
#         <li>user_engagement_score</li>
#       </ul>
#     </li>
#
# <li><strong>User demographics</strong>
#       <ul>
#         <li>age</li>
#         <li>gender</li>
#         <li>country</li>
#         <li>urban_rural</li>
#         <li>income_level</li>
#         <li>employment_status</li>
#         <li>education_level</li>
#         <li>relationship_status</li>
#       </ul>
#     </li>
#
# <li><strong>Physical health</strong>
#       <ul>
#         <li>body_mass_index</li>
#         <li>blood_pressure_systolic</li>
#         <li>blood_pressure_diastolic</li>
#         <li>daily_steps_count</li>
#         <li>exercise_hours_per_week</li>
#         <li>sleep_hours_per_night</li>
#         <li>diet_quality</li>
#         <li>smoking</li>
#         <li>alcohol_frequency</li>
#       </ul>
#     </li>
#
# <li><strong>Mental &amp; social wellbeing</strong>
#       <ul>
#         <li>perceived_stress_score</li>
#         <li>self_reported_happiness</li>
#         <li>weekly_work_hours</li>
#         <li>hobbies_count</li>
#         <li>social_events_per_month</li>
#       </ul>
#     </li>
#
# <li><strong>Instagram usage patterns</strong>
#       <ul>
#         <li>daily_active_minutes_instagram</li>
#         <li>sessions_per_day</li>
#         <li>average_session_length_minutes</li>
#         <li>time_on_feed_per_day</li>
#         <li>time_on_explore_per_day</li>
#         <li>time_on_messages_per_day</li>
#         <li>time_on_reels_per_day</li>
#       </ul>
#     </li>
#
# <li><strong>Platform behaviour &amp; social reach</strong>
#       <ul>
#         <li>posts_created_per_week</li>
#         <li>reels_watched_per_day</li>
#         <li>stories_viewed_per_day</li>
#         <li>likes_given_per_day</li>
#         <li>comments_written_per_day</li>
#         <li>content_type_preference</li>
#         <li>notification_response_rate</li>
#         <li>followers_count</li>
#         <li>following_count</li>
#       </ul>
#     </li>
#   </ul>
#         </div>
